# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/stock_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     Stock_1     Stock_2    Stock_3     Stock_4     Stock_5
# 0  2020-01-01  101.764052  100.160928  99.494642   99.909756  101.761266
# 1  2020-01-02  102.171269   99.969968  98.682973  100.640755  102.528643
# 2  2020-01-03  103.171258   99.575237  98.182139  100.574847  101.887811
# 3  2020-01-04  105.483215   99.308641  97.149381  100.925017  101.490049
# 4  2020-01-05  107.453175   98.188428  99.575396  101.594411  101.604283

# %% [markdown]
# to display max columns

# %%
pd.pandas.set_option('display.max_columns',None)

# %%
df.shape
# Out:
# (365, 6)

# %% [markdown]
# **This dataset contains 365 rows and 6 columns.**

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Stock_1       0
# Stock_2       0
# Stock_3       0
# Stock_4       0
# Stock_5       0
# dtype: int64

# %% [markdown]
# **There are no null values in the dataset.**

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Stock_1', 'Stock_2', 'Stock_3', 'Stock_4', 'Stock_5'], dtype='object')

# %% [markdown]
# #'Unnamed: 0': It represents on which dates the stocks will be sold high or low.
# #Stock_1, Stock_2, Stock_3, Stock_4, Stock_5: These columns likely represent data related to five different stocks.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  365 non-null    object
#  1   Stock_1     365 non-null    float64
#  2   Stock_2     365 non-null    float64
#  3   Stock_3     365 non-null    float64
#  4   Stock_4     365 non-null    float64
#  5   Stock_5     365 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 17.2+ KB

# %%
df['Unnamed: 0']=pd.to_datetime((df['Unnamed: 0']))

# %%
df.dtypes
# Out:
# Unnamed: 0    datetime64[ns]
# Stock_1              float64
# Stock_2              float64
# Stock_3              float64
# Stock_4              float64
# Stock_5              float64
# dtype: object

# %%
df.describe()
# Out:
#                 Unnamed: 0     Stock_1     Stock_2     Stock_3     Stock_4  \
# count                  365  365.000000  365.000000  365.000000  365.000000
# mean   2020-07-01 00:00:00  107.772577   81.105216   94.519502  117.407560
# min    2020-01-01 00:00:00   91.474442   62.414219   81.111434   99.909756
# 25%    2020-04-01 00:00:00  101.603117   69.328263   89.788068  112.209912
# 50%    2020-07-01 00:00:00  107.421299   84.283525   94.495546  117.788079
# 75%    2020-09-30 00:00:00  113.741728   91.548859   99.919465  123.132365
# max    2020-12-30 00:00:00  121.901773  100.160928  107.588373  129.911386
# std                    NaN    7.398296   11.435212    6.519213    6.778527
#
#           Stock_5
# count  365.000000
# mean   106.866865
# min     99.833309
# 25%    103.927072
# 50%    106.411328
# 75%    109.178007
# max    116.243803
# std      3.760968

# %%
df.nunique()
# Out:
# Unnamed: 0    365
# Stock_1       365
# Stock_2       365
# Stock_3       365
# Stock_4       365
# Stock_5       365
# dtype: int64

# %% [markdown]
# #UNIVARIENT ANALYSIS
# **bold text**#NUMERICAL DATA
# #[stock_1,stock_2,stock_3,stock_4,stock_5]

# %%
sns.histplot(df['Stock_1'],color='violet')
# Out:
# <Axes: xlabel='Stock_1', ylabel='Count'>

# %% [markdown]
# **Conclusion:**fro this graph we conclude that the highest nunber of stock will be sold between the range of 100-115 and there is decrease in sales from 95-100.

# %%
sns.boxplot(df['Stock_1'],color='green')
# Out:
# <Axes: ylabel='Stock_1'>

# %% [markdown]
# **conclusion**:no outliers

# %%
sns.violinplot(df['Stock_1'],color='red')
# Out:
# <Axes: ylabel='Stock_1'>

# %% [markdown]
# **conclusion:**from this graph we conclude that mostly the stock get sold from 100-115.

# %%
sns.histplot(df['Stock_2'],color='orange')
# Out:
# <Axes: xlabel='Stock_2', ylabel='Count'>

# %% [markdown]
# **conclusion:**from this graph we conclude that the 90 rupees stock will be sold highly and there is slight increase decrease in stocks sold from 65-85.The least sold stock i00 and 75.

# %%
sns.boxplot(df['Stock_2'],color='grey')
# Out:
# <Axes: ylabel='Stock_2'>

# %% [markdown]
# **conclusion**:no outliers

# %%
sns.violinplot(df['Stock_2'],color='pink')
# Out:
# <Axes: ylabel='Stock_2'>

# %% [markdown]
# cocnclusion :from this graph we conclude that there is frequent increase and decrease in stock sold.

# %%
sns.rugplot(df['Stock_2'],color='red')
# Out:
# <Axes: xlabel='Stock_2'>

# %%
sns.histplot(df['Stock_3'],color='yellow')
# Out:
# <Axes: xlabel='Stock_3', ylabel='Count'>

# %% [markdown]
# **conclusion:**from this graph we conclude that 90,95 and 100 are the highest stocks sold and the least sold stocks are 105 and 85.

# %%
sns.boxplot(df['Stock_3'],color='brown')
# Out:
# <Axes: ylabel='Stock_3'>

# %% [markdown]
# **conclusion:**no outliers.

# %%
sns.violinplot(df['Stock_3'],color='blue')
# Out:
# <Axes: ylabel='Stock_3'>

# %% [markdown]
# **conclusion:**from this graph we conclude that the highest number of stocks sold from 95-105.

# %%
sns.rugplot(df['Stock_3'],color='black')
# Out:
# <Axes: xlabel='Stock_3'>

# %%
sns.histplot(df['Stock_4'],color='green')
# Out:
# <Axes: xlabel='Stock_4', ylabel='Count'>

# %% [markdown]
# **conclusion**:from this graph we conclude that the 125 is the highest to be sold and 130 is  the least selling stocks.

# %%
sns.boxplot(df['Stock_4'],color='orange')
# Out:
# <Axes: ylabel='Stock_4'>

# %% [markdown]
# **conclusion:**no outliers.

# %%
sns.violinplot(df['Stock_4'],color='green')
# Out:
# <Axes: ylabel='Stock_4'>

# %% [markdown]
# **conclusion:**from this graph we conclude that 110-125 are the most selling stocks.

# %%
sns.rugplot(df['Stock_4'],color='grey')
# Out:
# <Axes: xlabel='Stock_4'>

# %%
sns.histplot(df['Stock_5'],color='brown')
# Out:
# <Axes: xlabel='Stock_5', ylabel='Count'>

# %% [markdown]
# **conclusion:**from this graph we conclude that the highest selling stock is ranges between 105-107 and there is slight increase and decrease in other stocks.

# %%
sns.boxplot(df['Stock_5'],color='violet')
# Out:
# <Axes: ylabel='Stock_5'>

# %% [markdown]
# **conclusion**:no outliers.

# %%
sns.violinplot(df['Stock_5'],color='orange')
# Out:
# <Axes: ylabel='Stock_5'>

# %% [markdown]
# **conclusion:**from this graph we conclude that the highest number of stocks will be sold from 105.

# %%
sns.rugplot(df['Stock_5'],color='pink')
# Out:
# <Axes: xlabel='Stock_5'>

# %%
import plotly.express as px

# %%
fig = px.histogram(df,x="Stock_1",nbins = 1000, range_x = (1,200))


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df,x="Stock_2",nbins = 1000, range_x = (1,200))


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df,x="Stock_3",nbins = 1000, range_x = (1,200))


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig= px.histogram(df,x="Stock_4",nbins = 1000, range_x = (1,200))


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df,x="Stock_5",nbins = 1000, range_x = (1,200))


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **BIVARIENT** **ANALYSIS**
# #numerical vs numerical

# %%
df['Unnamed: 0'].unique()
# Out:
# <DatetimeArray>
# ['2020-01-01 00:00:00', '2020-01-02 00:00:00', '2020-01-03 00:00:00',
#  '2020-01-04 00:00:00', '2020-01-05 00:00:00', '2020-01-06 00:00:00',
#  '2020-01-07 00:00:00', '2020-01-08 00:00:00', '2020-01-09 00:00:00',
#  '2020-01-10 00:00:00',
#  ...
#  '2020-12-21 00:00:00', '2020-12-22 00:00:00', '2020-12-23 00:00:00',
#  '2020-12-24 00:00:00', '2020-12-25 00:00:00', '2020-12-26 00:00:00',
#  '2020-12-27 00:00:00', '2020-12-28 00:00:00', '2020-12-29 00:00:00',
#  '2020-12-30 00:00:00']
# Length: 365, dtype: datetime64[ns]

# %%
sns.lineplot(x='Unnamed: 0', y='Stock_1', data=df, color='red')
# Out:
# <Axes: xlabel='Unnamed: 0', ylabel='Stock_1'>

# %% [markdown]
# **conclusion:**from this graph we conclude that The stock experienced fluctuations, with a peak around mid-2020, followed by a significant decline toward the end of 2020. This suggests periods of volatility and an overall downward trend by the year's end.

# %%
sns.lineplot(x='Unnamed: 0',y='Stock_2',data=df,color='orange')
# Out:
# <Axes: xlabel='Unnamed: 0', ylabel='Stock_2'>

# %% [markdown]
# **conclusion:**from this graph we conclude that The stock experienced significant decline toward the end of 2021. This suggests periods of volatility and an overall downward trend by the year's end.

# %%
sns.lineplot(x='Unnamed: 0',y='Stock_3',data=df,color='brown')
# Out:
# <Axes: xlabel='Unnamed: 0', ylabel='Stock_3'>

# %% [markdown]
# **conclusion**:From this graph we conclude thate The stock experienced a significant dip around mid-2020, reaching its lowest point, but subsequently recovered and peaked towards late 2020. This indicates a recovery phase following earlier volatility.

# %%
sns.lineplot(x='Unnamed: 0',y='Stock_4',data=df,color='blue')
# Out:
# <Axes: xlabel='Unnamed: 0', ylabel='Stock_4'>

# %% [markdown]
# **conclusion:**from this graph we conclude that the stock experienced a signififcant fluctuations and it recovered the towards late 2021.

# %%
sns.lineplot(x='Unnamed: 0',y='Stock_5',data=df,color='green')
# Out:
# <Axes: xlabel='Unnamed: 0', ylabel='Stock_5'>

# %% [markdown]
# **cocnclusion:**From this graph we conclude that this stock experienced a fluctuations mid 2020 followed by a significant decline at year end 2021.This stock experiences downfall period.

# %%
sns.scatterplot(x=df['Stock_1'],y=df['Stock_2'],color='red')
# Out:
# <Axes: xlabel='Stock_1', ylabel='Stock_2'>

# %% [markdown]
# **Conclusion:**from this graph we conclude that this dataappears different clusters showing a non-linear relationship between the stock-1 and stock-2.It indicates the different ,arket conditions.

# %%
sns.scatterplot(x=df['Stock_1'],y=df['Stock_3'],color='orange')
# Out:
# <Axes: xlabel='Stock_1', ylabel='Stock_3'>

# %% [markdown]
# **cocnclusion:**from this graph we conclude that the stock-1 will be phasing the decilne phase while stock-3 will phasing the recovering phase.

# %%
sns.scatterplot(x=df['Stock_1'],y=df['Stock_4'],color='violet')
# Out:
# <Axes: xlabel='Stock_1', ylabel='Stock_4'>

# %% [markdown]
# **conclusion:**From this graph we conclude that compared with stock-1,stock-4 will be having the highest sales sold.

# %%
sns.scatterplot(x=df['Stock_1'],y=df['Stock_5'],color='blue')
# Out:
# <Axes: xlabel='Stock_1', ylabel='Stock_5'>

# %% [markdown]
# **cocnclusion:**From this graph we conclude that stock-5 will be having highest sales when compared with stock-1.

# %%
sns.scatterplot(x=df['Stock_2'],y=df['Stock_3'],color='orange')
# Out:
# <Axes: xlabel='Stock_2', ylabel='Stock_3'>

# %% [markdown]
# **conclusion:**From this graph we conclude that stock-3 will be sold highly when compared with stock-2.

# %%
sns.scatterplot(x=df['Stock_2'],y=df['Stock_4'],color='black')
# Out:
# <Axes: xlabel='Stock_2', ylabel='Stock_4'>

# %% [markdown]
# **conclusion:**From this graph we conclude that stock-4 will be sold highly while stock-2 experiencing a decline phase.

# %%
sns.scatterplot(x=df['Stock_2'],y=df['Stock_5'],color='green')
# Out:
# <Axes: xlabel='Stock_2', ylabel='Stock_5'>

# %% [markdown]
# **conclusion:**From this graph we conclude that stock-5 will be sold highly while stock-2 will having the lowest sales.

# %%
sns.scatterplot(x=df['Stock_3'],y=df['Stock_4'],color='purple')
# Out:
# <Axes: xlabel='Stock_3', ylabel='Stock_4'>

# %% [markdown]
# **conclusion:**From this graph we conclude that stock-4 will having highest sales while stock-3 will experiencing low sales.

# %%
sns.scatterplot(x=df['Stock_3'],y=df['Stock_5'],color='black')
# Out:
# <Axes: xlabel='Stock_3', ylabel='Stock_5'>

# %% [markdown]
# **conclusion:**From this graph we conclude that stock-3 will having the highest sales while stock-5 experiencing low sales.

# %%
sns.scatterplot(x=df['Stock_4'],y=df['Stock_5'],color='orange')
# Out:
# <Axes: xlabel='Stock_4', ylabel='Stock_5'>

# %% [markdown]
# **conclusion:**From this graph we conclude that both stock-4 and stock-5 having equal sales.
